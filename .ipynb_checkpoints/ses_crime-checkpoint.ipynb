# %% [markdown]
# # How do socioeconomic factors affect crime rates in Seattle?
# ## Chantria Im, Ellie Velez, and Nawaf Osman

# %% [raw]
# # Install packages
# import sys
# !{sys.executable} -m pip install pandas
# !{sys.executable} -m pip install requests
# !{sys.executable} -m pip install dill

# %%
# Import libraries
import pandas as pd
import requests
import re
import dill # Notebook caching
import time

# %%
# Load datasets
crime_df = pd.read_csv('./data/SPD_Crime_Data__2008-Present_20240226.csv')
poverty_df = pd.read_csv('./data/Poverty_and_Near_Poverty_Map_Full_Data_data.csv', converters={'Census Tract': str.strip})
income_df = pd.read_csv('./data/ACSST5Y2018.S1903-Data.csv')

# %%
# Remove rows with missing Longitude and Latitude values
crime_df = crime_df[(crime_df['Longitude'] != 0) & (crime_df['Latitude'] != 0)]

# Filter for only 2018 entries
crime_df['Report DateTime'] = pd.to_datetime(crime_df['Report DateTime'], format='%m/%d/%Y %I:%M:%S %p')
crime_df = crime_df[crime_df['Report DateTime'].dt.year == 2018]

# Add Census Tract column
crime_df['Census Tract'] = pd.Series(dtype='string')

# %% [raw]
# # Fill Census Tract column with corresponding census tract numbers
# i = 0
# while i < len(crime_df):
#     # Make a request using the Census Geocoder API to get a row's census tract data based on the row's longtitude and latitude values
#     payload = {'benchmark': 'Public_AR_Current', 'vintage': 'ACS2018_Current', 'x': crime_df['Longitude'].iloc[i], 'y': crime_df['Latitude'].iloc[i], 'format': 'json', 'layers': 'Census Tracts'}
#     try:
#         r = requests.get(f'https://geocoding.geo.census.gov/geocoder/geographies/coordinates', params=payload)
#     except requests.Timeout:
#         time.sleep(300)
#         continue
#     # Extract the census tract number from the response and store it in the Census Tract column
#     crime_df['Census Tract'].iloc[i] = re.findall('\d+\.\d+|\d+', r.json()['result']['geographies']['Census Tracts'][0]['NAME'])[0]
#     i += 1
#
# # Backup dataframe to disk
# crime_df.to_csv('./data/crime.csv')

# %%
# Cache the dataframe
# %store crime_df
# Reload the dataframe from cache rather than recomputing (5+ hours)
# %store -r crime_df
crime_df
# Out:
#         Report Number  Offense ID  Offense Start DateTime  \
# 41275     2018-487339  7644443754  12/31/2018 11:39:00 PM
# 41276     2018-487178  7696639702  12/31/2018 07:00:00 PM
# 41277     2018-487186  7664183259  12/31/2018 09:14:00 PM
# 41278     2018-487085  7685572628  12/31/2018 03:00:00 PM
# 41279     2018-487216  7631819895  12/31/2018 09:33:00 PM
# ...               ...         ...                     ...
# 1071747   2018-336488  7663881810  09/08/2018 10:32:00 PM
# 1071748   2018-336488  7663881807  09/08/2018 10:32:00 PM
# 1080980   2018-350575  7669099329  09/19/2018 05:43:00 PM
# 1080981   2018-103499  7676453184  03/23/2018 01:38:00 PM
# 1093490   2018-480789  7692840487  12/26/2018 07:50:00 AM
#
#            Offense End DateTime     Report DateTime Group A B  \
# 41275                       NaN 2018-12-31 23:39:00         A
# 41276                       NaN 2018-12-31 23:14:00         A
# 41277                       NaN 2018-12-31 22:52:00         B
# 41278    12/31/2018 03:30:00 PM 2018-12-31 22:09:00         A
# 41279                       NaN 2018-12-31 21:33:00         A
# ...                         ...                 ...       ...
# 1071747                     NaN 2018-09-08 22:32:00         A
# 1071748                     NaN 2018-09-08 22:32:00         A
# 1080980                     NaN 2018-09-19 17:43:00         A
# 1080981                     NaN 2018-03-23 14:02:00         A
# 1093490                     NaN 2018-12-26 07:50:00         B
#
#         Crime Against Category                      Offense Parent Group  \
# 41275                 PROPERTY                  STOLEN PROPERTY OFFENSES
# 41276                 PROPERTY                             LARCENY-THEFT
# 41277                  SOCIETY               DRIVING UNDER THE INFLUENCE
# 41278                 PROPERTY                             LARCENY-THEFT
# 41279                 PROPERTY  DESTRUCTION/DAMAGE/VANDALISM OF PROPERTY
# ...                        ...                                       ...
# 1071747                SOCIETY                    DRUG/NARCOTIC OFFENSES
# 1071748                 PERSON                          ASSAULT OFFENSES
# 1080980               PROPERTY                BURGLARY/BREAKING&ENTERING
# 1080981                SOCIETY                    DRUG/NARCOTIC OFFENSES
# 1093490                SOCIETY               DRIVING UNDER THE INFLUENCE
#
#                                           Offense Offense Code Precinct  \
# 41275                    Stolen Property Offenses          280        W
# 41276                           All Other Larceny          23H        S
# 41277                 Driving Under the Influence          90D        E
# 41278                    Theft From Motor Vehicle          23F        E
# 41279    Destruction/Damage/Vandalism of Property          290        N
# ...                                           ...          ...      ...
# 1071747                  Drug/Narcotic Violations          35A        S
# 1071748                        Aggravated Assault          13A        S
# 1080980              Burglary/Breaking & Entering          220        S
# 1080981                  Drug/Narcotic Violations          35A        W
# 1093490               Driving Under the Influence          90D       SW
#
#         Sector Beat                     MCPP  \
# 41275        Q   Q1                 MAGNOLIA
# 41276        R   R2  CLAREMONT/RAINIER VISTA
# 41277        E   E2             CAPITOL HILL
# 41278        C   C2     MONTLAKE/PORTAGE BAY
# 41279        J   J2                GREENWOOD
# ...        ...  ...                      ...
# 1071747      S   S1                NEW HOLLY
# 1071748      S   S1                NEW HOLLY
# 1080980      R   R1          MID BEACON HILL
# 1080981      M   M3      DOWNTOWN COMMERCIAL
# 1093490      F   F1               HIGH POINT
#
#                                   100 Block Address   Longitude   Latitude  \
# 41275                     26XX BLOCK OF BISHOP PL W -122.404822  47.644858
# 41276                   35XX BLOCK OF RAINIER AVE S -122.292905  47.571475
# 41277                         14TH AVE / E UNION ST -122.314167  47.612917
# 41278    LAKE WASHINGTON BLVD E / E INTERLAKEN BLVD -122.297248  47.630773
# 41279                        1XX BLOCK OF N 85TH ST -122.357312  47.690607
# ...                                             ...         ...        ...
# 1071747               71XX BLOCK OF HOLLY PARK DR S -122.287444  47.539097
# 1071748               71XX BLOCK OF HOLLY PARK DR S -122.287444  47.539097
# 1080980                    40XX BLOCK OF 14TH AVE S -122.314717  47.568641
# 1080981                       15XX BLOCK OF 3RD AVE -122.338247  47.610246
# 1093490                 SW HOLLY ST / SYLVAN WAY SW -122.370607  47.542832
#
#         Census Tract
# 41275             56
# 41276            101
# 41277             75
# 41278             62
# 41279          17.01
# ...              ...
# 1071747       110.01
# 1071748       110.01
# 1080980       100.01
# 1080981           81
# 1093490       107.01
#
# [72558 rows x 18 columns]
